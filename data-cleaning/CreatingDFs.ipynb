# %%
import csv

import pandas as pd

df = pd.read_csv("10112_R2_CSV.csv")

df.head()
# Out:
#      Timepoint  District ID  School ID  Teacher ID  Condition  Obs. Entry  \
# 0      :00-:20            1       1011       10112          1           1
# 1      :20-:40            1       1011       10112          1           2
# 2     :40-1:00            1       1011       10112          1           3
# 3  1:00 - 1:20            1       1011       10112          1           4
# 4    1:20-1:40            1       1011       10112          1           5
#
#    ESL Strategy  Curriculum  Physical Group  Activity Structure  Mode  \
# 0            10          14               5                   8    18
# 1            10          14               5                   8    18
# 2            10          14               5                   8     3
# 3            10          14               5                   8     3
# 4            10          14               5                  10    18
#
#    Language Content  Lang. of Instruction(T)  Lang. of Instruction(S)  Round
# ...
